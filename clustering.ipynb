# %% [markdown]
# ## Cluster visulaization notebook

# %% [markdown]
# #### imports

# %%
from src.mindmap.clustering_system import MindmapClusteringSystem

# %%
mindmap=  MindmapClusteringSystem()

# %%
result=mindmap.process_document('/Users/maryamsaad/Documents/Graduation_Proj/junk/chapter4_GT.json', document_type="json")
# Out:
# 📄 Processing document (json)...
# 📚 Extracted 7 raw texts
# 📝 Processed 7 text segments
# 🔢 Generating embeddings...
# 🎯 Applying dynamic clustering...
# 🎯 Strategy: simple
# 📊 Cluster range: 2-3
# 🔍 Finding optimal clusters for 7 samples...
# Testing cluster range: 2 to 3
#
# 📊 Testing Agglomerative Clustering...
#    n_clusters=2: sil=0.437, score=0.476
#    n_clusters=3: sil=0.402, score=0.594
#
# 🏆 Optimal Configuration:
#    Parameters: {'n_clusters': 3}
#    Score: 0.594

# %%
# Create different types of visualizations
mindmap.visualize_mindmap(result, visualization_type='interactive')
# Out:
# 🎨 Creating interactive visualization...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Create different types of visualizations
# ----> 2 mindmap.visualize_mindmap(result, visualization_type='interactive')
#
# File ~/Documents/self_study/thoughtflow/src/mindmap/clustering_system.py:243, in MindmapClusteringSystem.visualize_mindmap(self, result, visualization_type, save_path)
#     240 print(f"🎨 Creating {visualization_type} visualization...")
#     242 if visualization_type == 'interactive' or visualization_type == 'all':
# --> 243     self._create_interactive_mindmap(embeddings, labels, texts, branches, save_path)
#     245 if visualization_type == 'static' or visualization_type == 'all':
#     246     self._create_static_mindmap(embeddings, labels, texts, branches, save_path)
#
# ...

# %%
mindmap.visualize_mindmap(result, visualization_type='static')
# Out:
# 🎨 Creating static visualization...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 mindmap.visualize_mindmap(result, visualization_type='static')
#
# File ~/Documents/self_study/thoughtflow/src/mindmap/clustering_system.py:246, in MindmapClusteringSystem.visualize_mindmap(self, result, visualization_type, save_path)
#     243     self._create_interactive_mindmap(embeddings, labels, texts, branches, save_path)
#     245 if visualization_type == 'static' or visualization_type == 'all':
# --> 246     self._create_static_mindmap(embeddings, labels, texts, branches, save_path)
#     248 if visualization_type == 'network' or visualization_type == 'all':
#     249     self._create_network_mindmap(embeddings, labels, texts, branches, save_path)
#
# ...

# %%
mindmap.visualize_mindmap(result, visualization_type='network')
# Out:
# 🎨 Creating network visualization...
# /Users/maryamsaad/Documents/self_study/thoughtflow/myenv/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning:
#
# Glyph 128376 (\N{SPIDER WEB}) missing from font(s) DejaVu Sans.

# %%
mindmap.visualize_mindmap(result, visualization_type='dashboard')
# Out:
# 🎨 Creating dashboard visualization...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 mindmap.visualize_mindmap(result, visualization_type='dashboard')
#
# File ~/Documents/self_study/thoughtflow/src/mindmap/clustering_system.py:252, in MindmapClusteringSystem.visualize_mindmap(self, result, visualization_type, save_path)
#     249     self._create_network_mindmap(embeddings, labels, texts, branches, save_path)
#     251 if visualization_type == 'dashboard' or visualization_type == 'all':
# --> 252     self._create_mindmap_dashboard(result, save_path)
#
# File ~/Documents/self_study/thoughtflow/src/mindmap/clustering_system.py:603, in MindmapClusteringSystem._create_mindmap_dashboard(self, result, save_path)
#     600     fig.write_html(f"{save_path}_dashboard.html")
#     601     print(f"💾 Dashboard saved to {save_path}_dashboard.html")
# ...
